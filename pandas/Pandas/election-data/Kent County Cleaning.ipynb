# %%
import pandas as pd
import leather

# %%
# Read data into CSV
straight = pd.read_csv('kent-straight-party-RAW.csv', index_col=0, thousands=',')
straight
# Out:
#                                  Registered voters  Ballots Cast Turnout  \
# TOTALS: 252 of 252
# TOTAL                                       501117        363694  72.58%
# Ada Township Precinct 1                       1316          1095  83.21%
# Ada Township Precinct 2                       2428          1979  81.51%
# Ada Township Precinct 3                       1397          1152  82.46%
# Ada Township Precinct 4                       1168           982  84.08%
# ...                                            ...           ...     ...
# Wyoming City Ward 3 Precinct 26               1349           971  71.98%
# Wyoming City Ward 3 Precinct 27               1310           967  73.82%
# Wyoming City Ward 3 Precinct 28               2183          1784  81.72%
# Wyoming City Ward 3 Precinct 29               1839          1538  83.63%
# Wyoming City Ward 3 Precinct 30               2198          1824  82.98%
#
#                                  Democratic Party  Republican Party  \
# ...

# %%
# Read data into CSV
individual = pd.read_csv('kent-individual-RAW.csv', index_col=0, thousands=',')
individual
# Out:
#                                  Registered voters  Ballots Cast Turnout  \
# TOTALS: 252 of 252
# TOTAL                                       501117        363695  72.58%
# Ada Township Precinct 1                       1316          1095  83.21%
# Ada Township Precinct 2                       2428          1979  81.51%
# Ada Township Precinct 3                       1397          1152  82.46%
# Ada Township Precinct 4                       1168           982  84.08%
# ...                                            ...           ...     ...
# Wyoming City Ward 3 Precinct 26               1349           971  71.98%
# Wyoming City Ward 3 Precinct 27               1310           967  73.82%
# Wyoming City Ward 3 Precinct 28               2183          1784  81.72%
# Wyoming City Ward 3 Precinct 29               1839          1538  83.63%
# Wyoming City Ward 3 Precinct 30               2198          1824  82.98%
#
#                                  Joseph R. Biden w/ Kamala D. Harris  \
# ...

# %%
straight.to_csv('kent-county-straight-party.csv')

# %%
individual.to_csv('kent-county-individual.csv')
