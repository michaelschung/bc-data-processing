# %%
import pandas as pd

# %% [markdown]
# # HW 8: 2020 Election Data
#
# In this assignment, we'll take a look at data from the 2020 Presidential Election, and use Pandas to help us process it down to answer a couple questions.

# %%
election = pd.read_csv('president_county_candidate.csv', index_col=0)
election
# Out:
#                      county      candidate party  total_votes    won
# state
# Delaware        Kent County      Joe Biden   DEM        44552   True
# Delaware        Kent County   Donald Trump   REP        41009  False
# Delaware        Kent County   Jo Jorgensen   LIB         1044  False
# Delaware        Kent County  Howie Hawkins   GRN          420  False
# Delaware  New Castle County      Joe Biden   DEM       195034   True
# ...                     ...            ...   ...          ...    ...
# Arizona     Maricopa County   Donald Trump   REP       993691  False
# Arizona     Maricopa County   Jo Jorgensen   LIB        31608  False
# Arizona       Mohave County   Donald Trump   REP        78534   True
# Arizona       Mohave County      Joe Biden   DEM        24831  False
# Arizona       Mohave County   Jo Jorgensen   LIB         1302  False
#
# [31112 rows x 5 columns]

# %% [markdown]
# ## What percentage of the vote did Biden receive in Otsego County, NY?
#
# Group the data by (state, county), calculate the percentage of the vote that each candidate received within each county, and add that data as a new column in the original DataFrame. Name this new column `pct_county`.
#
# Then, query for Otsego County, NY, to see what percentage Biden received there.

# %%
# Group the data by (state, country)
counties = election.groupby(['state', 'county'])
counties.groups
# Out:
# {('Alabama',
#   'Autauga County'): Index(['Alabama', 'Alabama', 'Alabama', 'Alabama'], dtype='object', name='state'),
#  ('Alabama',
#   'Baldwin County'): Index(['Alabama', 'Alabama', 'Alabama', 'Alabama'], dtype='object', name='state'),
#  ('Alabama',
#   'Barbour County'): Index(['Alabama', 'Alabama', 'Alabama', 'Alabama'], dtype='object', name='state'),
#  ('Alabama',
#   'Bibb County'): Index(['Alabama', 'Alabama', 'Alabama', 'Alabama'], dtype='object', name='state'),
#  ('Alabama',
#   'Blount County'): Index(['Alabama', 'Alabama', 'Alabama', 'Alabama'], dtype='object', name='state'),
#  ('Alabama',
#   'Bullock County'): Index(['Alabama', 'Alabama', 'Alabama', 'Alabama'], dtype='object', name='state'),
#  ('Alabama',
#   'Butler County'): Index(['Alabama', 'Alabama', 'Alabama', 'Alabama'], dtype='object', name='state'),
#  ('Alabama',
#   'Calhoun County'): Index(['Alabama', 'Alabama', 'Alabama', 'Alabama'], dtype='object', name='state'),
#  ('Alabama',
# ...

# %%
# Write a method that calculates the percentage of each value in a group with respect to the whole group.
# This is very similar to the pct function from Investigating Transform.
def pct(x):
    return x / sum(x)

# %%
# Use the above method to calculate the percentage of each value with respect to its group, and add
# this information as a new column in the original DataFrame.
election['pct_vote'] = counties['total_votes'].transform(pct)
new_york = election.loc['New York']
new_york[new_york['county'] == 'Otsego County']
# Out:
#                  county      candidate party  total_votes    won  pct_vote
# state
# New York  Otsego County   Donald Trump   REP        12682   True  0.567681
# New York  Otsego County      Joe Biden   DEM         9138  False  0.409042
# New York  Otsego County   Jo Jorgensen   LIB          336  False  0.015040
# New York  Otsego County  Howie Hawkins   GRN          101  False  0.004521
# New York  Otsego County   Brock Pierce   IND           83  False  0.003715

# %% [markdown]
# *Note: I know that you can answer the question directly by querying out the few rows from Otsego County and then calculating the percentage by hand. However you **must** complete this problem for the entire DataFrame first, and then query the updated table for Otsego County.*

# %% [markdown]
# ## Would Trump have won if he received the Libertarian votes?
#
# A common sentiment expressed in the aftermath of the 2020 election was that Trump would have won if those who voted Libertarian had voted for him instead. Use the data to determine if that's a true statement.
#
# *Hint: We already know that if the few key swing states (Arizona, Georgia, Pennsylvania, Wisconsin) had flipped, then Trump would have won the electoral college vote. Thus, the easiest way to solve this problem is to check to see if those particular states would have flipped.*

# %%
# Group the data by state
states = election.groupby('state')
states.groups
# Out:
# {'Alabama': Index(['Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         ...
#         'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama', 'Alabama',
#         'Alabama', 'Alabama', 'Alabama', 'Alabama'],
#        dtype='object', name='state', length=268),
#  'Alaska': Index(['Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska',
#         'Alaska', 'Alaska', 'Alaska',
#         ...
#         'Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska', 'Alaska',
#         'Alaska', 'Alaska', 'Alaska'],
#        dtype='object', name='state', length=280),
#  'Arizona': Index(['Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona',
#         'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona',
#         'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona',
#         'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona', 'Arizona',
# ...

# %%
# Find each state that would have flipped if the Libertarian votes had gone Republican
# Loop through each state
for name, state in states:
    # Group state by candidate
    state_cand = state.groupby('candidate')
    # Find total vote count per candidate
    totals = state_cand['total_votes'].sum()
    # Grab each candidate's total
    biden = totals['Joe Biden']
    trump = totals['Donald Trump']
    jorg = totals['Jo Jorgensen']
    # Calculate difference between biden and trump
    diff = biden - trump
    # Only print if Jorgensen's count is greater than Biden's lead
    if (biden > trump and jorg > diff):
        hypothetical_trump_lead = trump + jorg - biden
        print(name, hypothetical_trump_lead)
# Out:
# Arizona 39422
# Georgia 48001
# Pennsylvania 24781
# Wisconsin 17909

# %% [markdown]
# Conclusion: Yes. If all Libertarian voters had voted for Trump, then he would have won the popular vote for these four states, and thus their electoral votes.
