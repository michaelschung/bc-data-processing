# %%
import pandas as pd

# %%
books_url = 'goodreads_books.csv'

books = pd.read_csv(books_url, index_col=0)
books
# Out:
#                                                       title  \
# id
# 630104                                         Inner Circle
# 9487                                      A Time to Embrace
# 6050894                                            Take Two
# 39030                                             Reliquary
# 998       The Millionaire Next Door: The Surprising Secr...
# ...                                                     ...
# 15743072                             The Stranger I Married
# 18143905     The Opposite of Loneliness: Essays and Stories
# 1466878                                   Sadako will leben
# 630103                                          Confessions
# 6922622                       Going Rogue: An American Life
#
#                                                        link  \
# id
# 630104    https://www.goodreads.com//book/show/630104.In...
# 9487      https://www.goodreads.com//book/show/9487.A_Ti...
# ...

# %%
books.columns
# Out:
# Index(['title', 'link', 'series', 'cover_link', 'author', 'author_link',
#        'rating_count', 'review_count', 'average_rating', 'five_star_ratings',
#        'four_star_ratings', 'three_star_ratings', 'two_star_ratings',
#        'one_star_ratings', 'number_of_pages', 'date_published', 'publisher',
#        'original_title', 'genre_and_votes', 'isbn', 'isbn13', 'asin',
#        'settings', 'characters', 'awards', 'amazon_redirect_link',
#        'worldcat_redirect_link', 'recommended_books', 'books_in_series',
#        'description'],
#       dtype='object')

# %%
books.drop(['link',
            'cover_link',
            'author_link',
            'five_star_ratings',
            'four_star_ratings',
            'three_star_ratings',
            'two_star_ratings',
            'one_star_ratings',
            'asin',
            'awards',
            'amazon_redirect_link',
            'worldcat_redirect_link',
            'recommended_books',], axis=1, inplace=True)

# %%
books
# Out:
#                                                       title  \
# id
# 630104                                         Inner Circle
# 9487                                      A Time to Embrace
# 6050894                                            Take Two
# 39030                                             Reliquary
# 998       The Millionaire Next Door: The Surprising Secr...
# ...                                                     ...
# 15743072                             The Stranger I Married
# 18143905     The Opposite of Loneliness: Essays and Stories
# 1466878                                   Sadako will leben
# 630103                                          Confessions
# 6922622                       Going Rogue: An American Life
#
#                        series                                     author  \
# id
# 630104           (Private #5)                  Kate Brian, Julian Peploe
# 9487       (Timeless Love #2)                            Karen Kingsbury
# ...

# %%
books.to_csv('goodreads_books_reduced.csv')
